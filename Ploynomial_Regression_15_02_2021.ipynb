# %% [markdown]
# <a href="https://colab.research.google.com/github/ShounakD1991/UDEMY_MACHINE_LEARNING_A-Z_HANDS_ON_PYTHON_IN_DATA_SCIENCE/blob/main/Ploynomial_Regression_15_02_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# ## Polynomial Linear Regression
# ---

# %% [markdown]
# ---
# ### Importing the libraries
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---
# ### Importing the dataset
# ---

# %%
df=pd.read_csv("/content/drive/MyDrive/PGDSE_STUDY_MATERIAL/Udemy Courses/Machine Learning A-Z Hands-On Python & R In Data Science/Part 2 - Regression/Section 6 - Polynomial Regression/Python/Position_Salaries.csv")
df.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
x=df.iloc[:,1].values
y=df.iloc[:,-1].values

# %% [markdown]
# ---
# ### Training the Linear Regression model on the whole Dataset
# ---

# %%
from sklearn.linear_model import LinearRegression
lregressor=LinearRegression()
x_lin=lregressor.fit(x.reshape(-1,1),y.reshape(-1,1))

# %% [markdown]
# ---
# ### Training the Linear Regression model on the whole Dataset
# ---

# %%
from sklearn.preprocessing import PolynomialFeatures
pregressor=PolynomialFeatures(degree=2)
x_poly=pregressor.fit_transform(x.reshape(-1,1))
lin_reg_2=LinearRegression()
lin_reg_2.fit(x_poly,y.reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ---
# ### Visualising the Linear Regression Results
# ---

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.scatterplot(data=df,hue="Position",y="Salary",x='Level')
plt.plot(x.reshape(-1,1),lregressor.predict(x.reshape(-1,1)),color='red',label="Linear Regression Line",ls="--")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.legend()
plt.title("Scatter Plot of Position and Salary")
plt.show()

# %% [markdown]
# ---
# ### Visualising the Polynomial Regression Results
# ---

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.scatterplot(data=df,hue="Position",y="Salary",x='Level')
plt.plot(x.reshape(-1,1),lin_reg_2.predict(pregressor.fit_transform(x.reshape(-1,1))),color='red',label="Polynomial Regression Line",ls="--")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.legend()
plt.title("Scatter Plot of Position and Salary")
plt.show()

# %% [markdown]
# ---
# ### Visualising the Polynomial Regression Results (for higher resolution and smoother curve)
# ---

# %%
pregressor=PolynomialFeatures(degree=4)
x_poly=pregressor.fit_transform(x.reshape(-1,1))
lin_reg_2=LinearRegression()
lin_reg_2.fit(x_poly,y.reshape(-1,1))
plt.figure(figsize=(10,5),dpi=100)
sns.scatterplot(data=df,hue="Position",y="Salary",x='Level')
plt.plot(x.reshape(-1,1),lin_reg_2.predict(pregressor.fit_transform(x.reshape(-1,1))),color='red',label="Polynomial Regression Line",ls="--")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.legend()
plt.title("Scatter Plot of Position and Salary")
plt.show()

# %% [markdown]
# ---
# ### Predicting a new result with Linear Regression
# ---

# %%
x_lin.predict([[6.5]])
# Out:
# array([[330378.78787879]])

# %% [markdown]
# ---
# ### Predicting a new result with Polynomial Regression
# ---

# %%
lin_reg_2.predict(pregressor.fit_transform([[6.5]]))
# Out:
# array([[158862.45265155]])
